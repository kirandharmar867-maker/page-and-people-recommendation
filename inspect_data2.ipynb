# %%
# project work folw:

# %%
import json
def load_data(file_name):
    with open(file_name, "r")as f:
        data=json.load(f)
    return data
data=load_data("data2.json")
for user in data["users"]:
    print(f"{user['id']}.user:{user['name']}, friends:{user['friends']}")
print("\npages information: ")
for page in data["pages"]:
    print(f"page_ID: {page['id']}, page_name:{page['name']}")
# Out:
# 1.user:Amit, friends:[2, 3]
# 2.user:Priya, friends:[1, 4]
# 3.user:, friends:[1]
# 4.user:Sara, friends:[2, 2]
# 5.user:Amit, friends:[]
#
# pages information:
# page_ID: 101, page_name:Python Developers
# page_ID: 102, page_name:Data Science Enthusiasts
# page_ID: 103, page_name:AI & ML Community
# page_ID: 104, page_name:Web Dev Hub
# page_ID: 104, page_name:Web Development
